# %% [markdown]
# ### Download datasets to server

# %%
# kaggle api key 
pip install kaggle
mkdir -p ~/.kaggle
echo '{"username":"zhongchu****","key":"ca******"}' > ~/.kaggle/kaggle.json

# 设置权限
chmod 600 ~/.kaggle/kaggle.json

# 学术加速
source /etc/network_turbo

kaggle competitions download -c physionet-ecg-image-digitization

# %% [markdown]
# ### Runpod

# %%
ssh o1c49lw4ogngjm-64410fbf@ssh.runpod.io -i ~/.ssh/runpod_ed25519
# 简化ssh
ssh runpod
